# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
walmart = pd.read_csv('data/walmart.csv')
walmart
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
typeA = walmart[walmart["type"] == "A"]
typeA
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
typeA_stats = typeA.groupby(["store", "date"])["weekly_sales"]
list(typeA_stats)
# Out:
# [((1, '2010-02-05'),
#   0       24924.50
#   12      50605.27
#   24      13740.12
#   36      39954.04
#   48      32229.38
#            ...
#   818     64494.87
#   830     56655.39
#   842    106690.06
#   866     32153.04
#   878     10891.37
#   Name: weekly_sales, Length: 73, dtype: float64),
#  ((1, '2010-03-05'),
#   1       21827.90
#   13      48397.98
#   25      12275.58
#   37      38086.19
#   49      23082.14
#            ...
#   819     63550.08
#   831     59201.37
#   843    112807.75
#   867     31576.47
#   879     10903.65
#   Name: weekly_sales, Length: 73, dtype: float64),
#  ((1, '2010-03-12'),
#   517   -698.0
#   Name: weekly_sales, dtype: float64),
#  ((1, '2010-04-02'),
#   2       57258.43
#   14      47450.50
#   26      11157.08
#   38      37809.49
#   50      29967.92
#            ...
#   820     63245.00
#   832     66172.11
#   844    111466.37
#   868     30149.20
#   880     14740.14
#   Name: weekly_sales, Length: 72, dtype: float64),
# ...

# %%
myList = [1, 2, 3, 4, 5]
for i, j in enumerate(myList):
    print(i, j)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
